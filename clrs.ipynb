# %% [markdown]
# # CLRS-30
#
# Implements a new methods for Neural Algorithmic Reasoning, using the CLRS-30 benchmark.
#
# The Github repository code is available in https://github.com/falreis/clrs.
#
# If this code helps your work, please consider citing it!

# %%
# !git clone https://github.com/falreis/clrs.git
# %cd clrs

# %%
# !pip install -r requeriments/requeriments.txt

# %%
# !python3 run.py 10000 dfs
