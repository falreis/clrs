# %%
import numpy

# %%
import os
#os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
#os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
from tensorflow import keras

if tf.test.gpu_device_name():
    print('Default GPU Name: {}'.format(device_lib.list_local_devices()))
else:
    print("Please install GPU version of TF")
    print('Acesse o menu Edit > Notebook Settings')
    print('Escolha a opção "Hardware Accelerator: GPU"')
    print('Importe novamente as bibliotecas e execute o código novamente')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow.python.client import device_lib
#       3 from tensorflow import keras
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install tensorflow[and-cuda]
# Out:
# ...
#   Using cached nvidia_cublas_cu12-12.5.3.2-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cuda_nvcc_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cudnn_cu12-9.3.0.75-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.2.3.61-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.6.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.6.3.83-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.5.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...

# %%
from jax import jit, random, config
config.update('jax_enable_x64', True)
import jax
import jax.numpy as jnp
print(jax.devices())
# Out:
# [CudaDevice(id=0)]

# %%
#pip install tensorflow[and-cuda]
#pip install jax[cuda]
# Out:
#   Cell In[4], line 1
#     pip install tensorflow[and-cuda]
#         ^
# SyntaxError: invalid syntax

# %%
pip install git+file:///home/falreis/Me/doutorado/clrs/
# Out:
# ...
#   Cloning file:///home/falreis/Me/doutorado/clrs/ to /tmp/pip-req-build-3xa9hk_x
#   Running command git clone --filter=blob:none --quiet file:///home/falreis/Me/doutorado/clrs/ /tmp/pip-req-build-3xa9hk_x
# ...
#   Resolved file:///home/falreis/Me/doutorado/clrs/ to commit 66a855b328211c6887b6e8353122de0f1d4e30a2
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached chex-0.1.88-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached dm_haiku-0.0.13-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached jax-0.4.38-py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached jaxlib-0.4.38-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.0 kB)
# ...
#   Using cached ml_collections-1.0.0-py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached optax-0.2.4-py3-none-any.whl.metadata (8.3 kB)
# ...

# %%
pip install git+file:///home/falreis/Me/doutorado/clrs/
# Out:
# ...
#   Cloning file:///home/falreis/Me/doutorado/clrs/ to /tmp/pip-req-build-p4u_v51y
#   Running command git clone --filter=blob:none --quiet file:///home/falreis/Me/doutorado/clrs/ /tmp/pip-req-build-p4u_v51y
# ...
#   Resolved file:///home/falreis/Me/doutorado/clrs/ to commit 66a855b328211c6887b6e8353122de0f1d4e30a2
#   Preparing metadata (setup.py) ... done
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python3 examples/run.py
# Out:
# Traceback (most recent call last):
#   File "/home/falreis/Me/doutorado/clrs/clrs/examples/run.py", line 23, in <module>
#     from absl import app
# ModuleNotFoundError: No module named 'absl'
